# %%
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract

import ibapi
import pandas as pd

import threading
import time

class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        self.data = [] #Initialize variable to store candle

    def historicalData(self, reqId, bar):
        print(f'Time: {bar.date} Open: {bar.open} High: {bar.high} Low: {bar.low} Close: {bar.close}')
        self.data.append([bar.date, bar.open, bar.high, bar.low, bar.close])
        
def run_loop():
    app.run()

app = IBapi()
app.connect('127.0.0.1', 7496, 125)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

#Create contract object
def index_contract(symbol, secType='STK', exchange='NYSE'):
    ''' custom function to create contract '''
    contract = Contract()
    contract.symbol = symbol
    contract.secType = secType
    contract.exchange = exchange
    contract.currency = "USD"
    return contract

NQ_contract = index_contract('SPY')
#Request historical candles
#app.reqHistoricalData(1, eurusd_contract, '20220504 9:00:00', '1 D', '1 min', 'TRADES', 0, 2, False, [])
app.reqHistoricalData(1, NQ_contract, '20230327-16:00:00', '1 D', '1 min', 'TRADES', 1, 2, False, [])
time.sleep(5) #sleep to allow enough time for data to be returned

#Working with Pandas DataFrames
import pandas

df = pandas.DataFrame(app.data, columns=['DateTime', 'Open', 'High', 'Low', 'Close'])
df['DateTime'] = pandas.to_datetime(df['DateTime']) 
df.to_csv('spy_ib.csv')  

display(df.head())


app.disconnect()
# Out:
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usopt
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR 1 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 183.93 to 183
# Time: 1679923800 Open: 398.11 High: 398.34 Low: 398.01 Close: 398.12
# Time: 1679923860 Open: 398.08 High: 398.2 Low: 397.99 Close: 398.02
# Time: 1679923920 Open: 398.02 High: 398.32 Low: 397.97 Close: 398.21
# ...

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_46632/281403043.py in <module>
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined
